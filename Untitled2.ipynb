# %% [markdown]
# Домашнее задание. Урок 6.

# %% [markdown]
# Задание 1

# %%
import pandas as pd
import numpy as np

# %%
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

# %%
X = zp
Y = ks

MX = X.mean()
MY = Y.mean()

cov = ((X - MX) * (Y - MY)).sum() / (X.shape[0] - 1)
cov
# Out:
# 10175.37777777778

# %%
np.cov(X, Y, ddof=1)
# Out:
# array([[ 3882.93333333, 10175.37777778],
#        [10175.37777778, 33854.32222222]])

# %%
np.corrcoef(X, Y)
# Out:
# array([[1.        , 0.88749009],
#        [0.88749009, 1.        ]])

# %%
Std_X = np.sqrt(((X - MX) ** 2).sum() / (X.shape[0] - 1))
Std_Y = np.sqrt(((Y - MY) ** 2).sum() / (Y.shape[0] - 1))

Std_X, Std_Y
# Out:
# (62.31318747531162, 183.99544076477068)

# %%
corr = cov/ (Std_X * Std_Y)
corr
# Out:
# 0.8874900920739164

# %% [markdown]
# Ответ: corr = 0.887, cov = 10175

# %% [markdown]
# Задание 2

# %%
iq = np.array([131, 125, 115, 122, 131, 115, 107, 99, 125, 111])

# %%
m_iq = iq.mean()
std_iq = iq.std()
n = iq.shape[0]
alpha = 0.05

# %%
from scipy import stats

t1 = stats.t.ppf(alpha / 2, df=n - 1)
t2 = stats.t.ppf(1 - alpha / 2, df=n - 1)

t1, t2
# Out:
# (-2.262157162740992, 2.2621571627409915)

# %%
m_iq - t2 * std_iq / np.sqrt(n), m_iq - t1 * std_iq / np.sqrt(n)
# Out:
# (110.9432125583706, 125.25678744162938)

# %% [markdown]
# Ответ: Доверительный интервал при надёжности 0.95 -> (110.943, 125,257)

# %% [markdown]
# Задание 3

# %%
h_std = 5
n = 27
h_mean = 174.2
alpha = 0.05

# %%
t1 = stats.t.ppf(alpha / 2, df=n - 1)
t2 = stats.t.ppf(1 - alpha / 2, df=n - 1)

t1, t2
# Out:
# (-2.0555294386428713, 2.055529438642871)

# %%
h_mean - t2 * h_std / np.sqrt(n), h_mean - t1 * h_std / np.sqrt(n)
# Out:
# (172.2220658754539, 176.17793412454608)

# %% [markdown]
# Ответ: Доверительный интервал при надёжности 0.95 -> (172.2, 176,18)
